# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas import Series,DataFrame

# %%
url='https://in.images.search.yahoo.com/search/images;_ylt=AwrtgWKRwVRn.R8qb1q9HAx.;_ylu=c2VjA3NlYXJjaARzbGsDYXNzaXN0;_ylc=--?p=food&fr=mcafee&fr2=sa-gp-search&ei=UTF-8&x=wrt&type=E210IN826G0#id=0&iurl=https%3A%2F%2Fimages.pexels.com%2Fphotos%2F1860208%2Fpexels-photo-1860208.jpeg%3Fauto%3Dcompress%26cs%3Dtinysrgb%26dpr%3D2%26h%3D650%26w%3D940&action=click'

# %%
a=requests.get(url)

# %%
print(a.content)
# Out:
# b'<!DOCTYPE html><html><head><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"><title>food - Yahoo India Image Search results</title><link rel="stylesheet" href="https://s.yimg.com/pv/static/lib/isyc_yahoo_srp_desktop_4ddd74f0a37ef72b9a79e3163113c601.css"><noscript><style>#main.hidden-visible{visibility:visible;}#main .sres-cntr{width:1119px}#main .south-assist{padding-top:20px}</style></noscript><style>#yucs-top-list{margin-left: 10px !important;width: 972px;}#yucs{ width: auto!important; margin-right: 10px; height: 0; }.yucs-fl-left{height:0;width:0;}.yucs-fl-right{margin: 8px 0 0 0;} #yucs a#yucs-home_link, #yucs-nav a#yucs-nav_button{ display: none!important; }</style><style type=\'text/css\'>#logo .logo{display:block;text-indent:-9999px;height:21px;width:88px;background-image:url(\'https://s.yimg.com/pv/static/img/yahoo-search-logo-88x21.png\');*background-image:url(\'https://s.yimg.com/pv/static/img/yahoo-search-logo-88x21.gif\');background-po
# ...

# %%
b=BeautifulSoup(a.content,'lxml')
print(b)
# Out:
# <!DOCTYPE html>
# ...

# %%
c=b.findAll(class_='img')
print(c)
# Out:
# [<a aria-label="Cooked Food · Free Stock Photo" class="img" href="/images/view?back=https%3A%2F%2Fin.images.search.yahoo.com%2Fsearch%2Fimages%3Fp%3Dfood%26ei%3DUTF-8%26type%3DE210IN826G0%26fr%3Dmcafee%26fr2%3Dsa-gp-search%26tab%3Dorganic%26ri%3D1&amp;w=1880&amp;h=1253&amp;imgurl=images.pexels.com%2Fphotos%2F1860208%2Fpexels-photo-1860208.jpeg%3Fauto%3Dcompress%26cs%3Dtinysrgb%26dpr%3D2%26h%3D650%26w%3D940&amp;rurl=https%3A%2F%2Fwww.pexels.com%2Fphoto%2Fcooked-food-1860208%2F&amp;size=319KB&amp;p=food&amp;oid=f0035f5ad534cb1f91767528c1918372&amp;fr2=sa-gp-search&amp;fr=mcafee&amp;tt=Cooked+Food+%C2%B7+Free+Stock+Photo&amp;b=0&amp;ni=21&amp;no=1&amp;ts=&amp;tab=organic&amp;sigr=1Lnz8vk.aPKA&amp;sigb=.QqGP4ZZi.ww&amp;sigi=6MluOYpipOn_&amp;sigt=tshsXCiwf.wZ&amp;.crumb=&amp;fr=mcafee&amp;fr2=sa-gp-search&amp;type=E210IN826G0"><img alt="" class="process" data-src="https://tse2.mm.bing.net/th?id=OIP.5XZGu7I9rqQc67dpzviiugHaE7&amp;pid=Api&amp;P=0&amp;w=300&amp;h=300" style="width:256.727828
# ...

# %%
d=c.find(class id="yui_3_5_1_1_1733607843769_611')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 d=c.find(href='/images/view;_ylt=AwrtgWKjwVRnhP8qT8q9HAx.;_ylu=c2VjA3NyBHNsawNpbWcEb2l…SmMOGUIU8wt&.crumb=DUcByTAUbMb&fr=mcafee&fr2=sa-gp-search&type=E210IN826G0')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# ...

# %%
print(d)
# Out:
# None
